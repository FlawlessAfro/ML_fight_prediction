# %%
import pandas as pd

# %%
df_original = pd.read_csv('../bronze/raw_total_fight_data.csv', delimiter=';')
df_copy = df_original.copy().dropna()

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'])
df_copy['date'] = df_copy['date'].dt.strftime('%d-%m-%Y')
df_copy
# Out:
# C:\Users\AleksanderHalfstadAa\AppData\Local\Temp\ipykernel_12412\3450990719.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_copy['date'] = pd.to_datetime(df_copy['date'])
#           R_fighter           B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 0      Adrian Yanez       Gustavo Lopez     2     0  41 of 103   23 of 51
# 1      Trevin Giles       Roman Dolidze     0     0   27 of 57   32 of 67
# 2       Tai Tuivasa     Harry Hunsucker     1     0   14 of 18     2 of 6
# 3     Cheyanne Buys   Montserrat Conejo     0     0   31 of 65   15 of 41
# 4     Marion Reneau       Macy Chiasson     0     0   30 of 63  51 of 138
# ...             ...                 ...   ...   ...        ...        ...
# 6007  Remco Pardoel  Alberta Cerra Leon     0     0     4 of 6     1 of 3
# 6008   Orlando Wiet    Robert Lucarelli     0     0    8 of 12     2 of 6
# ...

# %%
df_original=pd.read_csv('../bronze/ufc-master.csv')
df_odds = df_original.copy()
#df_odds= df_odds[['R_fighter', 'B_fighter','R_odds','B_odds','date']]
df_odds['date']
# Out:
# 0       2021-10-02
# 1       2021-10-02
# 2       2021-10-02
# 3       2021-10-02
# 4       2021-10-02
#            ...
# 4891     3/21/2010
# 4892     3/21/2010
# 4893     3/21/2010
# 4894     3/21/2010
# 4895     3/21/2010
# Name: date, Length: 4896, dtype: object

# %%
df_original=pd.read_csv('../bronze/fighter_details.csv')
df_fight_data = df_original.copy().dropna()

# %%
fight_data = pd.merge(df_copy, df_odds, on=['R_fighter', 'B_fighter', 'date'], how='left')
fight_data
# Out:
#           R_fighter           B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 0      Adrian Yanez       Gustavo Lopez     2     0  41 of 103   23 of 51
# 1      Trevin Giles       Roman Dolidze     0     0   27 of 57   32 of 67
# 2       Tai Tuivasa     Harry Hunsucker     1     0   14 of 18     2 of 6
# 3     Cheyanne Buys   Montserrat Conejo     0     0   31 of 65   15 of 41
# 4     Marion Reneau       Macy Chiasson     0     0   30 of 63  51 of 138
# ...             ...                 ...   ...   ...        ...        ...
# 5866  Remco Pardoel  Alberta Cerra Leon     0     0     4 of 6     1 of 3
# 5867   Orlando Wiet    Robert Lucarelli     0     0    8 of 12     2 of 6
# 5868  Johnny Rhodes       David Levicki     0     0   11 of 17     4 of 5
# 5869  Patrick Smith          Ray Wizard     0     0     1 of 1     1 of 1
# 5870   Scott Morris      Sean Daugherty     0     0     1 of 1     0 of 4
#
#      R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... last_round  \
# ...

# %%
fight_data
# Out:
# Empty DataFrame
# Columns: [R_fighter, B_fighter, R_KD, B_KD, R_SIG_STR., B_SIG_STR., R_SIG_STR_pct, B_SIG_STR_pct, R_TOTAL_STR., B_TOTAL_STR., R_TD, B_TD, R_TD_pct, B_TD_pct, R_SUB_ATT, B_SUB_ATT, R_REV, B_REV, R_CTRL, B_CTRL, R_HEAD, B_HEAD, R_BODY, B_BODY, R_LEG, B_LEG, R_DISTANCE, B_DISTANCE, R_CLINCH, B_CLINCH, R_GROUND, B_GROUND, win_by, last_round, last_round_time, Format, Referee, date, location, Fight_type, Winner, R_odds, B_odds]
# Index: []
#
# [0 rows x 43 columns]
