# %%
import pandas as pd

# %%
df_original = pd.read_csv('../bronze/raw_total_fight_data.csv', delimiter=';')
df_copy = df_original.copy().dropna()

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'])
df_copy['date'] = df_copy['date'].dt.strftime('%d-%m-%Y')
df_copy
# Out:
#           R_fighter           B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 0      Adrian Yanez       Gustavo Lopez     2     0  41 of 103   23 of 51
# 1      Trevin Giles       Roman Dolidze     0     0   27 of 57   32 of 67
# 2       Tai Tuivasa     Harry Hunsucker     1     0   14 of 18     2 of 6
# 3     Cheyanne Buys   Montserrat Conejo     0     0   31 of 65   15 of 41
# 4     Marion Reneau       Macy Chiasson     0     0   30 of 63  51 of 138
# ...             ...                 ...   ...   ...        ...        ...
# 6007  Remco Pardoel  Alberta Cerra Leon     0     0     4 of 6     1 of 3
# 6008   Orlando Wiet    Robert Lucarelli     0     0    8 of 12     2 of 6
# 6009  Johnny Rhodes       David Levicki     0     0   11 of 17     4 of 5
# 6010  Patrick Smith          Ray Wizard     0     0     1 of 1     1 of 1
# 6011   Scott Morris      Sean Daugherty     0     0     1 of 1     0 of 4
#
#      R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0              39%           45%    41 of 103     23 of 51  ...   0 of 0
# 1              47%           47%     43 of 73    75 of 110  ...   1 of 2
# 2              77%           33%     14 of 18       2 of 6  ...   0 of 0
# 3              47%           36%     49 of 87   136 of 168  ...   0 of 0
# 4              47%           36%     59 of 93    92 of 184  ...   2 of 4
# ...            ...           ...          ...          ...  ...      ...
# 6007           66%           33%     20 of 22      9 of 11  ...   0 of 2
# 6008           66%           33%     11 of 15       2 of 6  ...   0 of 0
# 6009           64%           80%     74 of 86    95 of 102  ...   1 of 1
# 6010          100%          100%       1 of 1       2 of 2  ...   0 of 0
# 6011          100%            0%       2 of 2       1 of 5  ...   0 of 0
#
#                     win_by last_round last_round_time         Format  \
# 0                   KO/TKO          3            0:27  3 Rnd (5-5-5)
# 1     Decision - Unanimous          3            5:00  3 Rnd (5-5-5)
# 2                   KO/TKO          1            0:49  3 Rnd (5-5-5)
# 3     Decision - Unanimous          3            5:00  3 Rnd (5-5-5)
# 4     Decision - Unanimous          3            5:00  3 Rnd (5-5-5)
# ...                    ...        ...             ...            ...
# 6007            Submission          1            9:51  No Time Limit
# 6008                KO/TKO          1            2:50  No Time Limit
# 6009                KO/TKO          1           12:13  No Time Limit
# 6010            Submission          1            0:58  No Time Limit
# 6011            Submission          1            0:20  No Time Limit
#
#             Referee        date                location  \
# 0     Chris Tognoni  20-03-2021  Las Vegas, Nevada, USA
# 1         Herb Dean  20-03-2021  Las Vegas, Nevada, USA
# 2         Herb Dean  20-03-2021  Las Vegas, Nevada, USA
# 3        Mark Smith  20-03-2021  Las Vegas, Nevada, USA
# 4        Mark Smith  20-03-2021  Las Vegas, Nevada, USA
# ...             ...         ...                     ...
# 6007  John McCarthy  11-03-1994   Denver, Colorado, USA
# 6008  John McCarthy  11-03-1994   Denver, Colorado, USA
# 6009  John McCarthy  11-03-1994   Denver, Colorado, USA
# 6010  John McCarthy  11-03-1994   Denver, Colorado, USA
# 6011  John McCarthy  11-03-1994   Denver, Colorado, USA
#
#                      Fight_type             Winner
# 0             Bantamweight Bout       Adrian Yanez
# 1             Middleweight Bout       Trevin Giles
# 2              Heavyweight Bout        Tai Tuivasa
# 3      Women's Strawweight Bout  Montserrat Conejo
# 4     Women's Bantamweight Bout      Macy Chiasson
# ...                         ...                ...
# 6007           Open Weight Bout      Remco Pardoel
# 6008           Open Weight Bout       Orlando Wiet
# 6009           Open Weight Bout      Johnny Rhodes
# 6010           Open Weight Bout      Patrick Smith
# 6011           Open Weight Bout       Scott Morris
#
# [5871 rows x 41 columns]

# %%
df_original=pd.read_csv('../bronze/ufc-master.csv')
df_odds = df_original.copy()
#df_odds= df_odds[['R_fighter', 'B_fighter','R_odds','B_odds','date']]

df_odds['date'] = df_odds['date'].apply(lambda x: pd.to_datetime(x).strftime('%m-%d-%Y'))

df_odds
# Out:
#                 R_fighter        B_fighter  R_odds  B_odds        R_ev  \
# 0           Thiago Santos    Johnny Walker  -150.0     130   66.666667
# 1           Alex Oliveira       Niko Price   170.0    -200  170.000000
# 2          Misha Cirkunov  Krzysztof Jotko   110.0    -130  110.000000
# 3     Alexander Hernandez     Mike Breeden  -675.0     475   14.814815
# 4             Joe Solecki     Jared Gordon  -135.0     115   74.074074
# ...                   ...              ...     ...     ...         ...
# 4891         Duane Ludwig    Darren Elkins  -155.0     135   64.516129
# 4892          John Howard   Daniel Roberts  -210.0     175   47.619048
# 4893       Brendan Schaub    Chase Gormley  -260.0     220   38.461538
# 4894          Mike Pierce    Julio Paulino  -420.0     335   23.809524
# 4895         Eric Schafer      Jason Brilz   140.0    -160  140.000000
#
#             B_ev        date                   location country Winner  ...  \
# 0     130.000000  10-02-2021     Las Vegas, Nevada, USA     USA    Red  ...
# 1      50.000000  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# 2      76.923077  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# 3     475.000000  10-02-2021     Las Vegas, Nevada, USA     USA    Red  ...
# 4     115.000000  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# ...          ...         ...                        ...     ...    ...  ...
# 4891  135.000000  03-21-2010  Broomfield, Colorado, USA     USA   Blue  ...
# 4892  175.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4893  220.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4894  335.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4895   62.500000  03-21-2010  Broomfield, Colorado, USA     USA   Blue  ...
#
#       finish_details finish_round finish_round_time  total_fight_time_secs  \
# 0                NaN          5.0              5:00                 1500.0
# 1                NaN          3.0              5:00                  900.0
# 2                NaN          3.0              5:00                  900.0
# 3              Punch          1.0              1:20                   80.0
# 4                NaN          3.0              5:00                  900.0
# ...              ...          ...               ...                    ...
# 4891             NaN          1.0              0:44                   44.0
# 4892           Punch          1.0              2:01                  121.0
# 4893         Punches          1.0              0:47                   47.0
# 4894             NaN          3.0              5:00                  900.0
# 4895             NaN          3.0              5:00                  900.0
#
#       r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  r_ko_odds  b_ko_odds
# 0          800.0       900.0      2000.0      1600.0     -110.0      175.0
# 1          450.0       350.0       700.0      1100.0      550.0      120.0
# 2          550.0       275.0       275.0      1400.0      600.0      185.0
# 3          175.0       900.0       500.0      3500.0      110.0     1100.0
# 4          165.0       200.0       400.0      1200.0      900.0      600.0
# ...          ...         ...         ...         ...        ...        ...
# 4891         NaN         NaN         NaN         NaN        NaN        NaN
# 4892         NaN         NaN         NaN         NaN        NaN        NaN
# 4893         NaN         NaN         NaN         NaN        NaN        NaN
# 4894         NaN         NaN         NaN         NaN        NaN        NaN
# 4895         NaN         NaN         NaN         NaN        NaN        NaN
#
# [4896 rows x 119 columns]

# %%
df_odds['finish_details'].unique()
# Out:
# array([nan, 'Punch', 'Punches', 'Elbow', 'Armbar', 'Rear Naked Choke',
#        'Kick', "D'Arce Choke", 'Elbows', 'Heel Hook', 'Guillotine Choke',
#        'Flying Knee', 'Kimura', 'Knee', 'Triangle Choke', 'Kneebar',
#        'Anaconda Choke', 'Arm Triangle', 'Knees', 'Ankle Lock',
#        'Neck Crank', 'Peruvian Necktie', 'Spinning Back Fist',
#        'Other - Choke', 'Other - Lock', 'Slam', 'Spinning Back Kick',
#        'Omoplata', 'North-South Choke', 'Injury', 'Kicks', 'Keylock'],
#       dtype=object)

# %%
red_win = df_odds.loc[df_odds['Winner'] == 'Red']
red_win['Winner'] = red_win['R_fighter']
blue_win = df_odds.loc[df_odds['Winner'] == 'Blue']
blue_win['Winner'] = blue_win['B_fighter']
df_winner = pd.concat([red_win,blue_win])
# Out:
# C:\Users\AleksanderHalfstadAa\AppData\Local\Temp\ipykernel_12412\4098735810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   red_win['Winner'] = red_win['R_fighter']
# C:\Users\AleksanderHalfstadAa\AppData\Local\Temp\ipykernel_12412\4098735810.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blue_win['Winner'] = blue_win['B_fighter']

# %%
red_win = df_odds.loc[df_odds['Winner'] == 'Red']
red_win['Winner'] = red_win['R_fighter']
red_win['Winner']
# Out:
# C:\Users\AleksanderHalfstadAa\AppData\Local\Temp\ipykernel_12412\688126761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   red_win['Winner'] = red_win['R_fighter']
# 0                  Thiago Santos
# 3            Alexander Hernandez
# 8       Douglas Silva de Andrade
# 9                Stephanie Egger
# 10               Alejandro Perez
#                   ...
# 4888              Alessio Sakara
# 4889                  Clay Guida
# 4892                 John Howard
# 4893              Brendan Schaub
# 4894                 Mike Pierce
# Name: Winner, Length: 2859, dtype: object

# %%
df_winner['Winner'].value_counts()[:10]
# Out:
# Winner
# Donald Cerrone        23
# Dustin Poirier        20
# Charles Oliveira      19
# Neil Magny            18
# Max Holloway          18
# Jon Jones             17
# Rafael Dos Anjos      17
# Demian Maia           16
# Jim Miller            16
# Francisco Trinaldo    16
# Name: count, dtype: int64

# %%
win_counts = df_odds.groupby(['Winner', 'B_Stance', 'R_Stance']).size().reset_index(name='count')

# %%
blue_win_counts = df_odds[df_odds['Winner'] == 'Blue'].groupby(['B_Stance']).size().reset_index(name='Blue_win_count')
blue_win_counts
# Out:
#       B_Stance  Blue_win_count
# 0  Open Stance               1
# 1     Orthodox            1526
# 2     Southpaw             410
# 3       Switch              99
# 4      Switch                1

# %%
df_odds
# Out:
#                 R_fighter        B_fighter  R_odds  B_odds        R_ev  \
# 0           Thiago Santos    Johnny Walker  -150.0     130   66.666667
# 1           Alex Oliveira       Niko Price   170.0    -200  170.000000
# 2          Misha Cirkunov  Krzysztof Jotko   110.0    -130  110.000000
# 3     Alexander Hernandez     Mike Breeden  -675.0     475   14.814815
# 4             Joe Solecki     Jared Gordon  -135.0     115   74.074074
# ...                   ...              ...     ...     ...         ...
# 4891         Duane Ludwig    Darren Elkins  -155.0     135   64.516129
# 4892          John Howard   Daniel Roberts  -210.0     175   47.619048
# 4893       Brendan Schaub    Chase Gormley  -260.0     220   38.461538
# 4894          Mike Pierce    Julio Paulino  -420.0     335   23.809524
# 4895         Eric Schafer      Jason Brilz   140.0    -160  140.000000
#
#             B_ev        date                   location country Winner  ...  \
# 0     130.000000  10-02-2021     Las Vegas, Nevada, USA     USA    Red  ...
# 1      50.000000  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# 2      76.923077  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# 3     475.000000  10-02-2021     Las Vegas, Nevada, USA     USA    Red  ...
# 4     115.000000  10-02-2021     Las Vegas, Nevada, USA     USA   Blue  ...
# ...          ...         ...                        ...     ...    ...  ...
# 4891  135.000000  03-21-2010  Broomfield, Colorado, USA     USA   Blue  ...
# 4892  175.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4893  220.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4894  335.000000  03-21-2010  Broomfield, Colorado, USA     USA    Red  ...
# 4895   62.500000  03-21-2010  Broomfield, Colorado, USA     USA   Blue  ...
#
#       finish_details finish_round finish_round_time  total_fight_time_secs  \
# 0                NaN          5.0              5:00                 1500.0
# 1                NaN          3.0              5:00                  900.0
# 2                NaN          3.0              5:00                  900.0
# 3              Punch          1.0              1:20                   80.0
# 4                NaN          3.0              5:00                  900.0
# ...              ...          ...               ...                    ...
# 4891             NaN          1.0              0:44                   44.0
# 4892           Punch          1.0              2:01                  121.0
# 4893         Punches          1.0              0:47                   47.0
# 4894             NaN          3.0              5:00                  900.0
# 4895             NaN          3.0              5:00                  900.0
#
#       r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  r_ko_odds  b_ko_odds
# 0          800.0       900.0      2000.0      1600.0     -110.0      175.0
# 1          450.0       350.0       700.0      1100.0      550.0      120.0
# 2          550.0       275.0       275.0      1400.0      600.0      185.0
# 3          175.0       900.0       500.0      3500.0      110.0     1100.0
# 4          165.0       200.0       400.0      1200.0      900.0      600.0
# ...          ...         ...         ...         ...        ...        ...
# 4891         NaN         NaN         NaN         NaN        NaN        NaN
# 4892         NaN         NaN         NaN         NaN        NaN        NaN
# 4893         NaN         NaN         NaN         NaN        NaN        NaN
# 4894         NaN         NaN         NaN         NaN        NaN        NaN
# 4895         NaN         NaN         NaN         NaN        NaN        NaN
#
# [4896 rows x 119 columns]
